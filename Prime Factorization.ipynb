# %%
def prime_facto(n):
    factors = []
    i = 2
    while i <= n:
        if n%i == 0:
            factors.append(i)
            n = n/i
        else:
            i += 1
    return factors

# %%
print(prime_facto(10))
# Out:
# [2, 5]
